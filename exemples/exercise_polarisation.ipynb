# %%
import numpy as np
import fonction_polarisation as fp
import matplotlib.pyplot as plt
from IPython.display import display, Math, Latex

# %% [markdown]
# 1)

# %%
vect_jones_a = [1, (1-1j)]
vect_jones_b = [1/2, 1j]
vect_jones_c = [-2j, -2+1j]
vect_jones_d = [4, -1]
vect_jones_e = [1j, -1j]

theta_a, epsi_a, sens_a = fp.theta_epsilon_sens_j(vect_jones_a)
theta_b, epsi_b, sens_b = fp.theta_epsilon_sens_j(vect_jones_b)
theta_c, epsi_c, sens_c = fp.theta_epsilon_sens_j(vect_jones_c)
theta_d, epsi_d, sens_d = fp.theta_epsilon_sens_j(vect_jones_d)
theta_e, epsi_e, sens_e = fp.theta_epsilon_sens_j(vect_jones_e)

display(Math(r"\theta_{a} =" + str(theta_a) + " "+ r"\epsilon_{a} =" + str(epsi_a)))
display(Math(r"\theta_{b} =" + str(theta_b) + " "+ r"\epsilon_{b} =" + str(epsi_b)))
display(Math(r"\theta_{c} =" + str(theta_c) + " "+ r"\epsilon_{c} =" + str(epsi_c)))
display(Math(r"\theta_{d} =" + str(theta_d) + " "+ r"\epsilon_{d} =" + str(epsi_d)))
display(Math(r"\theta_{e} =" + str(theta_e) + " "+ r"\epsilon_{e} =" + str(epsi_e)))

psi_a, delta_a = fp.psidelta_j(vect_jones_a)
psi_b, delta_b = fp.psidelta_j(vect_jones_b)
psi_c, delta_c = fp.psidelta_j(vect_jones_c)
psi_d, delta_d = fp.psidelta_j(vect_jones_d)
psi_e, delta_e = fp.psidelta_j(vect_jones_e)

display(Math(r"\psi_{a} =" + str(psi_a) + " "+ r"\Delta_{a} =" + str(delta_a)))
display(Math(r"\psi_{b} =" + str(psi_b) + " "+ r"\Delta_{b} =" + str(delta_b)))
display(Math(r"\psi_{c} =" + str(psi_c) + " "+ r"\Delta_{c} =" + str(delta_c)))
display(Math(r"\psi_{d} =" + str(psi_d) + " "+ r"\Delta_{d} =" + str(delta_d)))
display(Math(r"\psi_{e} =" + str(psi_e) + " "+ r"\Delta_{e} =" + str(delta_e)))
# Out:
# $\displaystyle \theta_{a} =1.0172219678978514 \epsilon_{a} =0.36486382811348317$
# $\displaystyle \theta_{b} =1.5707963267948966 \epsilon_{b} =-0.46364760900080626$
# $\displaystyle \theta_{c} =-0.9078874949608805 \epsilon_{c} =0.54745703856724$
# $\displaystyle \theta_{d} =-0.24497866312686417 \epsilon_{d} =-2.8815218803467134e-17$
# $\displaystyle \theta_{e} =-0.7853981633974483 \epsilon_{e} =-6.123233995736766e-17$
# $\displaystyle \psi_{a} =0.9553166181245093 \Delta_{a} =-0.7853981633974483$
# $\displaystyle \psi_{b} =1.1071487177940904 \Delta_{b} =1.5707963267948966$
# $\displaystyle \psi_{c} =0.8410686705679303 \Delta_{c} =-2.0344439357957027$
# $\displaystyle \psi_{d} =0.24497866312686414 \Delta_{d} =3.141592653589793$
# $\displaystyle \psi_{e} =0.7853981633974483 \Delta_{e} =3.141592653589793$

# %% [markdown]
# 2)

# %%
vect_jones_E = [(1+1j), (3-1j)]
psi_E, delta_E = fp.psidelta_j(vect_jones_E)
display(Math(r"\psi_{E} =" + str(psi_E) + " "+ r"\Delta_{E} =" + str(delta_E)))
# Out:
# $\displaystyle \psi_{E} =1.1502619915109316 \Delta_{E} =-1.1071487177940904$

# %% [markdown]
# 3)

# %%
phi_x = 45*np.pi/180
phi_y = 0
delta = phi_y - phi_x

psi = 60*np.pi/180
retardeur = fp.retardeur(phi_x, phi_y, psi+np.pi/4)

vect_jones_0 = fp.j_theta_epsilon(60*np.pi/180, 0)
vect_jones_1 = np.dot(retardeur, vect_jones_0)
fp.graph_j(vect_jones_1)

# %%
phi_x = 0
phi_y = 25*np.pi/180
delta = phi_y - phi_x

psi = 150*np.pi/180
retardeur = fp.retardeur(phi_x, phi_y, psi+np.pi/4)

vect_jones_0 = fp.j_theta_epsilon(150*np.pi/180, 0)
vect_jones_1 = np.dot(retardeur, vect_jones_0)
fp.graph_j(vect_jones_1)
